# %%
import pandas as pd 
import scanpy as sc 
import numpy as np
import random
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"
# %config InlineBackend.figure_format='retina'

# %%
model_to_name = {
    'uce':'UCE',
    'scimilarity':'SCimilarity',
    'cellfishing':'CellFishing.jl',
    'scfoundation':'scFoundation',
    'scMulan':'scMuLan',
    'cellblast':'CellBlast',
    'scvi':'scVI',
    'geneformer':'Geneformer',
    'linearscvi':'LDVAE',
    'scgpt':'scGPT',
    'cellplm':'CellPLM',
    'pca':'PCA',
    'Random':'Random'
}

# %% [markdown]
# #### summarize results

# %%
import pandas as pd
celltypes=[
  "B cell",
  "CD4+ T cell",
  "CD14+ monocyte",
  "CD16+ monocyte",
  "Cytotoxic T cell",
  "Dendritic cell",
  "Megakaryocyte",
  "Natural killer cell",
  "Plasmacytoid dendritic cell"
]

acc_l = []
pre_l = []
recall_l = []
f1_l = []
model_l = []
celltype_l = []
thres_l = []
# for threshold in [0.88,0.9,0.92,0.94]:
for threshold in [5.0,10.0,15.0,20.0,25.0,30.0]:
  for celltype in celltypes:
      cell_acc = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/accuracy_1_{threshold}/{celltype}.csv',index_col=0)
      cell_pre = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/precision_1_{threshold}/{celltype}.csv',index_col=0)
      cell_recall = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/recall_1_{threshold}/{celltype}.csv',index_col=0)
      cell_f1 = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/f1_1_{threshold}/{celltype}.csv',index_col=0)      
      
      acc_l = acc_l + cell_acc.mean(1).values.tolist()
      pre_l = pre_l + cell_pre.mean(1).values.tolist()
      recall_l = recall_l + cell_recall.mean(1).values.tolist()
      f1_l = f1_l + cell_f1.mean(1).values.tolist()
      model_l = model_l + cell_acc.index.tolist()
      celltype_l = celltype_l + [celltype]*len(cell_acc)
      thres_l = thres_l + [threshold]*len(cell_acc)

data_df = pd.DataFrame({'model':model_l,'accuracy':acc_l,'precision':pre_l,'recall':recall_l,'f1':f1_l,'celltype':celltype_l,'threshold':thres_l})

# data_df.to_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/thres_summarized_data_ratio.csv')

# %%
celltypes=[
  "acinar",
  "activated_stellate",
  "alpha",
  "beta",
  "delta",
  "ductal",
  "endothelial",
  "epsilon",
  "gamma",
  "macrophage",
  "mast",
  "quiescent_stellate",
  "schwann"
]

acc_l = []
pre_l = []
model_l = []
celltype_l = []
thres_l = []
recall_l = []
f1_l = []
# for threshold in [0.88,0.9,0.92,0.94]:
for threshold in [5.0,10.0,15.0,20.0,25.0,30.0]:

  for celltype in celltypes:
      cell_acc = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/accuracy_1_{threshold}/{celltype}.csv',index_col=0)
      cell_pre = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/precision_1_{threshold}/{celltype}.csv',index_col=0)
      cell_recall = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/recall_1_{threshold}/{celltype}.csv',index_col=0)
      cell_f1 = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/f1_1_{threshold}/{celltype}.csv',index_col=0)      
      
      acc_l = acc_l + cell_acc.mean(1).values.tolist()
      pre_l = pre_l + cell_pre.mean(1).values.tolist()
      recall_l = recall_l + cell_recall.mean(1).values.tolist()
      f1_l = f1_l + cell_f1.mean(1).values.tolist()
      model_l = model_l + cell_acc.index.tolist()
      celltype_l = celltype_l + [celltype]*len(cell_acc)
      thres_l = thres_l + [threshold]*len(cell_acc)

data_df = pd.DataFrame({'model':model_l,'accuracy':acc_l,'precision':pre_l,'recall':recall_l,'f1':f1_l,'celltype':celltype_l,'threshold':thres_l})

# data_df.to_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/thres_summarized_data_ratio.csv')

# %%
celltypes=[
  "DC_c3-LAMP3",
  "Macro_c3-EREG",
  "Macro_c4-DNAJb1",
  "Neu_c4-RSAD2",
  "Neu_c6-FGF23",
]

acc_l = []
pre_l = []
model_l = []
celltype_l = []
thres_l = []
recall_l = []
f1_l = []
# for threshold in [0.88,0.9,0.92,0.94]:
for threshold in [5.0,10.0,15.0,20.0,25.0,30.0]:

  for celltype in celltypes:
      cell_acc = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/accuracy_1_{threshold}/{celltype}.csv',index_col=0)
      cell_pre = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/precision_1_{threshold}/{celltype}.csv',index_col=0)
      cell_recall = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/recall_1_{threshold}/{celltype}.csv',index_col=0)
      cell_f1 = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/f1_1_{threshold}/{celltype}.csv',index_col=0)      
      
      acc_l = acc_l + cell_acc.mean(1).values.tolist()
      pre_l = pre_l + cell_pre.mean(1).values.tolist()
      recall_l = recall_l + cell_recall.mean(1).values.tolist()
      f1_l = f1_l + cell_f1.mean(1).values.tolist()
      model_l = model_l + cell_acc.index.tolist()
      celltype_l = celltype_l + [celltype]*len(cell_acc)
      thres_l = thres_l + [threshold]*len(cell_acc)

data_df = pd.DataFrame({'model':model_l,'accuracy':acc_l,'precision':pre_l,'recall':recall_l,'f1':f1_l,'celltype':celltype_l,'threshold':thres_l})

# data_df.to_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/thres_summarized_data_ratio.csv')

# %%
acc_l = []
pre_l = []
model_l = []
thres_l = []
recall_l = []
f1_l = []
# for threshold in [0.88,0.9,0.92,0.94]:
for threshold in [5.0,10.0,15.0,20.0,25.0,30.0]:

  cell_acc = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/accuracy_1_{threshold}.csv',index_col=0)
  cell_pre = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/precision_1_{threshold}.csv',index_col=0)
  cell_recall = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/recall_1_{threshold}.csv',index_col=0)
  cell_f1 = pd.read_csv(f'/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/f1_1_{threshold}.csv',index_col=0)      
  
  acc_l = acc_l + cell_acc['mean'].values.tolist()
  pre_l = pre_l + cell_pre['mean'].values.tolist()
  recall_l = recall_l + cell_recall['mean'].values.tolist()
  f1_l = f1_l + cell_f1['mean'].values.tolist()
  model_l = model_l + cell_acc.index.tolist()
  thres_l = thres_l + [threshold]*len(cell_acc)

data_df = pd.DataFrame({'model':model_l,'accuracy':acc_l,'precision':pre_l,'recall':recall_l,'f1':f1_l,'threshold':thres_l})

# data_df.to_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/thres_summarized_data_ratio.csv')

# %% [markdown]
# #### visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

summ = pd.read_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/COVID/thres_summarized_data_ratio.csv',index_col=0)
plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='precision',
    hue='model',
    errorbar=None,
    marker="o"
)

plt.ylabel('Precision')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("COVID")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/COVID_pre_ratio.pdf',format='pdf')
plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='recall',
    hue='model',
    errorbar=None,
    marker="o"
)

plt.ylabel('Recall')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("COVID")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/COVID_recall_ratio.pdf',format='pdf')
plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='f1',
    hue='model',
    errorbar=None,
    marker="o"
)

plt.ylabel('F1 score')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("COVID")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/COVID_f1_ratio.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

summ = pd.read_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/PBMC/thres_summarized_data_ratio.csv',index_col=0)
plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='precision',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Precision')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("PBMC")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/PBMC_pre_ratio.pdf',format='pdf')

plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='recall',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Recall')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("PBMC")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/PBMC_recall_ratio.pdf',format='pdf')
plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='f1',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('F1 score')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("PBMC")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/PBMC_f1_ratio.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

summ = pd.read_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Pancreas/thres_summarized_data_ratio.csv',index_col=0)
plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='precision',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Precision')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Pancreas")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Pancreas_pre_ratio.pdf',format='pdf')

plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='recall',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Recall')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Pancreas")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Pancreas_recall_ratio.pdf',format='pdf')
plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='f1',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('F1 score')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Pancreas")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Pancreas_f1_ratio.pdf',format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

summ = pd.read_csv('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plot_codes/novel_cell_type/Panel_quantitative_benchmark/Ionocyte/thres_summarized_data_ratio.csv',index_col=0)
plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='precision',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Precision')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Ionocyte")
plt.tight_layout()
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Ionocyte_pre_ratio.pdf',format='pdf')

plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='recall',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('Recall')
plt.xlabel('Threshold (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Ionocyte")
plt.tight_layout() 
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Ionocyte_recall_ratio.pdf',format='pdf')
plt.show()

plt.figure(figsize=(5,3))
summ['threshold'] = summ['threshold'].astype(str)
sns.lineplot(
    data=summ,
    x='threshold',
    y='f1',
    hue='model',
    errorbar=None,
    marker="o"
)
plt.ylabel('F1 score')
plt.xlabel('Threshold (%)')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Ionocyte")
plt.tight_layout()  
# plt.savefig('/Users/liuxinyuan/Desktop/new_projects/cell_retrieval/plots/supplement/novel_cell_detection/Ionocyte_f1_ratio.pdf',format='pdf')
plt.show()
